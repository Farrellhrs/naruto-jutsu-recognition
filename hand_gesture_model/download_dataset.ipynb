# %%
import roboflow
print('roboflow import OK')
print(getattr(roboflow, '__version__', 'version unknown'))
# Out:
# roboflow import OK
# 1.2.16

# %%
# %pip install requests-toolbelt
# %pip install roboflow --no-deps
# Out:
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached roboflow-1.2.16-py3-none-any.whl.metadata (10 kB)
# Using cached roboflow-1.2.16-py3-none-any.whl (95 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from roboflow import Roboflow
rf = Roboflow(api_key=os.environ["ROBOFLOW_API_KEY"])
project = rf.workspace("adityas-workshop-kr2u8").project("naruto-hand-sign-cyq8u")
version = project.version(4)
dataset = version.download("yolov12")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to naruto-hand-sign-4 in yolov12:: 100%|██████████| 12296/12296 [00:00<00:00, 12876.67it/s]
